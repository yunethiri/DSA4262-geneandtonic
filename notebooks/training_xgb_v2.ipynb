# %%
import pandas as pd
import numpy as np
import json

from scipy.stats import skew, kurtosis
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, precision_recall_curve, auc

import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
df_labels= 'data/data.info.txt'
df_labels = pd.read_csv(df_labels, delimiter=',')

df_raw = 'data/dataset0.json'

# Open the file and read line by line (each line = one read)
with open(df_raw, 'r') as file:
    data_list = []
    for line in file:
        try:
            data = json.loads(line)  # Parse each line as a separate JSON object
            data_list.append(data)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON on line: {line}")
            print(f"Error message: {e}")

# %%
start_idx = 0
end_idx = 5

# iterate through 5-mers for the 7-mer, 
# out of all the first 5-mers, what is the proportion of the 5-mer
def compute_sequence_proportions(data_list, start_idx, stop_idx):
    """ 
    New function that takes in the data list and produces proportions of the occurence of the sequence
        start_idx: 0-indexed (if referring to first index, use 0)
        stop_idx: if stopping at second index, use 2
    """
    sequence_counter = Counter()
    total_sequences = 0

    # First pass: Count the occurrences of each sequence
    for data in data_list:
        for transcript_id, positions in data.items():
            for position, sequence_data in positions.items():
                for sequence in sequence_data.keys():
                    sequence = sequence[start_idx:stop_idx]
                    sequence_counter[sequence] += 1
                    total_sequences += 1

    # Compute the proportion for each sequences
    sequence_proportions = {seq: count / total_sequences for seq, count in sequence_counter.items()}
    return sequence_proportions

sequence_proportions_1 = compute_sequence_proportions(data_list, start_idx, end_idx)
sequence_proportions_2 = compute_sequence_proportions(data_list, start_idx+1, end_idx+1)
sequence_proportions_3 = compute_sequence_proportions(data_list, start_idx+2, end_idx+2)

# %%
sorted_data = dict(sorted(sequence_proportions_1.items(), key=lambda item: item[1], reverse=True))
plt.figure(figsize=(8, 5))
plt.bar(sorted_data.keys(), sorted_data.values())
plt.ylabel('Proportion')
plt.title('Proportions of Key Values')
plt.show()

# %%
# test to understand 

start_idx = 0
end_idx = 5

transcript_id = "ENST00000000233"
position = "244"

# sequence data 
sequence = "AAGACCA"
measurements = [[0.00299,2.06,125.0,0.0177,10.4,122.0,0.0093,10.9,84.1],
[0.00631,2.53,125.0,0.00844,4.67,126.0,0.0103,6.3,80.9],[0.00465,3.92,109.0,0.0136,12.0,124.0,0.00498,2.13,79.6], [0.00398,2.06,125.0,0.0083,5.01,130.0,0.00498,3.78,80.4],[0.00664,2.92,120.0,0.00266,3.94,129.0,0.013,7.15,82.2], [0.0103,3.83,123.0,0.00598,6.45,126.0,0.0153,1.09,74.8],[0.00398,3.75,126.0,0.00332,4.3,129.0,0.00299,1.93,81.9], [0.00498,3.93,127.0,0.00398,2.51,131.0,0.0111,3.47,79.4]]

scores_array = np.array(measurements)

# perform aggregate functions along columns 
# essentially getting mean, var, max etc. for dwell, sd and mean at -1, 0, 1
mean_scores = np.mean(scores_array, axis=0)
var_scores = np.var(scores_array, axis=0)
max_scores = np.max(scores_array, axis=0)
min_scores = np.min(scores_array, axis=0)
skew_scores = skew(scores_array, axis=0) # mean, median, mode not the same
kurtosis_scores = kurtosis(scores_array, axis=0) # how data disperse between distribution center and tails, 
# larger values -> heavy tails that are thickly concentrated with observations or that are long with extreme observation

# get 5-mers from the 7-mer, e.g. AAGACCA -> AAGAC, AGACC, GACCA
sequence_1 = sequence[start_idx:end_idx]
sequence_2 = sequence[start_idx+1:end_idx+1]
sequence_3 = sequence[start_idx+2:end_idx+2]

# mean of the diffs between the dwell time at positions -1 and 0 
measurement_diff_mean_dwell_one = np.mean(scores_array[:, 3] - scores_array[:, 0])
# mean of the diffs between the sd at positions -1 and 0 
measurement_diff_mean_sd_one = np.mean(scores_array[:, 4] - scores_array[:, 1])
# mean of the diffs between the mean at positions -1 and 0 
measurement_diff_mean_mean_one = np.mean(scores_array[:, 5] - scores_array[:, 2])

# do the same for the measurements at positions 0 and 1 
measurement_diff_mean_dwell_two = np.mean(scores_array[:, 6] - scores_array[:, 3])
measurement_diff_mean_sd_two = np.mean(scores_array[:, 7] - scores_array[:, 4])
measurement_diff_mean_mean_two = np.mean(scores_array[:, 8] - scores_array[:, 5])

# for each transcript position, 13 features 
transcript_position = {
                        'transcript_id': transcript_id, # e.g. "ENST00000000233"
                        'transcript_position': position, # e.g. 244
                        'proportion_1': sequence_proportions_1[sequence_1], # proportion of first 5-mer e.g.AAGAC
                        'proportion_2': sequence_proportions_2[sequence_2], # proportion of second 5-mer
                        'proportion_3': sequence_proportions_3[sequence_3], # proportion of third 5-mer
                        'pos': int(position), # 244
                        'diff_1_1': measurement_diff_mean_dwell_one, # mean of the diffs between the dwell time at positions -1 and 0 
                        'diff_1_2': measurement_diff_mean_sd_one, # mean of the diffs between the sd at positions -1 and 0 
                        'diff_1_3': measurement_diff_mean_mean_one , # mean of the diffs between the mean at positions -1 and 0 
                        'diff_2_1': measurement_diff_mean_dwell_two , # mean of the diffs between the dwell time at positions 0 and 1
                        'diff_2_2': measurement_diff_mean_sd_two, # mean of the diffs between the sd at positions 0 and 1
                        'diff_2_3': measurement_diff_mean_mean_two, # mean of the diffs between the mean at positions 0 and 1
                        'length': len(measurements) # number of measurements (reads) for the transcript_position
                    }

# for each measurement in one read, e.g. dwell, sd and mean at -1, 0, 1
for idx in range(scores_array.shape[1]): 
    # add the mean, var, max, min, skew and kurtosis 
    transcript_position.update({
        f'mean_{idx}': mean_scores[idx],
        f'var_{idx}': var_scores[idx],
        f'max_{idx}': max_scores[idx],
        f'min_{idx}': min_scores[idx],
        f'skewness_{idx}': skew_scores[idx],
        f'kurtosis_{idx}': kurtosis_scores[idx]
    })
# result should be 9 measurements x 6 aggregation functions -> 54 new features 

# for each measurement, dwell, sd and mean
# add all the aggregated scores for all three positions 
# e.g. mean_0c should be sum of means of dwell at position -1, 0 and 1
for i in range(3):
    transcript_position.update({
            f'mean_{i}c': mean_scores[i] + mean_scores[i+3] + mean_scores[i+6],
            f'var_{i}c': var_scores[i] + var_scores[i+3] + var_scores[i+6],
            f'max_{i}c': max_scores[i] + max_scores[i+3] + max_scores[i+6],
            f'min_{i}c': min_scores[i] + min_scores[i+3] + min_scores[i+6],
            f'skewness_{i}c': skew_scores[i] + skew_scores[i+3] + skew_scores[i+6],
            f'kurtosis_{i}c': kurtosis_scores[i] + kurtosis_scores[i+3] + skew_scores[i+6]
        })
# 3 measurements (dwell, sd and mean) x 6 aggregation functions -> 18

# total features = 13 + 54 + 18 = 85
    
transcript_position.keys()
# Out:
# dict_keys(['transcript_id', 'transcript_position', 'proportion_1', 'proportion_2', 'proportion_3', 'pos', 'diff_1_1', 'diff_1_2', 'diff_1_3', 'diff_2_1', 'diff_2_2', 'diff_2_3', 'length', 'mean_0', 'var_0', 'max_0', 'min_0', 'skewness_0', 'kurtosis_0', 'mean_1', 'var_1', 'max_1', 'min_1', 'skewness_1', 'kurtosis_1', 'mean_2', 'var_2', 'max_2', 'min_2', 'skewness_2', 'kurtosis_2', 'mean_3', 'var_3', 'max_3', 'min_3', 'skewness_3', 'kurtosis_3', 'mean_4', 'var_4', 'max_4', 'min_4', 'skewness_4', 'kurtosis_4', 'mean_5', 'var_5', 'max_5', 'min_5', 'skewness_5', 'kurtosis_5', 'mean_6', 'var_6', 'max_6', 'min_6', 'skewness_6', 'kurtosis_6', 'mean_7', 'var_7', 'max_7', 'min_7', 'skewness_7', 'kurtosis_7', 'mean_8', 'var_8', 'max_8', 'min_8', 'skewness_8', 'kurtosis_8', 'mean_0c', 'var_0c', 'max_0c', 'min_0c', 'skewness_0c', 'kurtosis_0c', 'mean_1c', 'var_1c', 'max_1c', 'min_1c', 'skewness_1c', 'kurtosis_1c', 'mean_2c', 'var_2c', 'max_2c', 'min_2c', 'skewness_2c', 'kurtosis_2c'])

# %%
# aggregating data_list
def create_aggregated_dataframe(data_list, sequence_proportions_1, sequence_proportions_2, sequence_proportions_3):
    rows = []
    for data in data_list:
        for transcript_id, positions in data.items():
            for position, sequence_data in positions.items():
                for sequence, measurements in sequence_data.items():
                    # Convert to numpy array for easier aggregation
                    scores_array = np.array(measurements)
                    
                    # Calculate the mean, variance, max, and min along the rows
                    mean_scores = np.mean(scores_array, axis=0)
                    var_scores = np.var(scores_array, axis=0)
                    max_scores = np.max(scores_array, axis=0)
                    min_scores = np.min(scores_array, axis=0)
                    skew_scores = skew(scores_array, axis=0)
                    kurtosis_scores = kurtosis(scores_array, axis=0)
                    sequence_1 = sequence[start_idx:end_idx]
                    sequence_2 = sequence[start_idx+1:end_idx+1]
                    sequence_3 = sequence[start_idx+2:end_idx+2]

                    measurement_diff_mean_dwell_one = np.mean(scores_array[:, 3] - scores_array[:, 0])
                    measurement_diff_mean_sd_one = np.mean(scores_array[:, 4] - scores_array[:, 1])
                    measurement_diff_mean_mean_one = np.mean(scores_array[:, 5] - scores_array[:, 2])

                    measurement_diff_mean_dwell_two = np.mean(scores_array[:, 6] - scores_array[:, 3])
                    measurement_diff_mean_sd_two = np.mean(scores_array[:, 7] - scores_array[:, 4])
                    measurement_diff_mean_mean_two = np.mean(scores_array[:, 8] - scores_array[:, 5])
                    transcript_position = {
                        'transcript_id': transcript_id,
                        'transcript_position': position,
                        'proportion_1': sequence_proportions_1[sequence_1],
                        'proportion_2': sequence_proportions_2[sequence_2],
                        'proportion_3': sequence_proportions_3[sequence_3],
                        'pos': int(position),
                        'diff_1_1': measurement_diff_mean_dwell_one,
                        'diff_1_2': measurement_diff_mean_sd_one,
                        'diff_1_3': measurement_diff_mean_mean_one ,
                        'diff_2_1': measurement_diff_mean_dwell_two ,
                        'diff_2_2': measurement_diff_mean_sd_two,
                        'diff_2_3': measurement_diff_mean_mean_two,
                        'length': len(measurements)
                    }
                    
                    for idx in range(scores_array.shape[1]): 
                        transcript_position.update({
                            f'mean_{idx}': mean_scores[idx],
                            f'var_{idx}': var_scores[idx],
                            f'max_{idx}': max_scores[idx],
                            f'min_{idx}': min_scores[idx],
                            f'skewness_{idx}': skew_scores[idx],
                            f'kurtosis_{idx}': kurtosis_scores[idx]
                        })
                    for i in range(3):
                        transcript_position.update({
                                f'mean_{i}c': mean_scores[i] + mean_scores[i+3] + mean_scores[i+6],
                                f'var_{i}c': var_scores[i] + var_scores[i+3] + var_scores[i+6],
                                f'max_{i}c': max_scores[i] + max_scores[i+3] + max_scores[i+6],
                                f'min_{i}c': min_scores[i] + min_scores[i+3] + min_scores[i+6],
                                f'skewness_{i}c': skew_scores[i] + skew_scores[i+3] + skew_scores[i+6],
                                f'kurtosis_{i}c': kurtosis_scores[i] + kurtosis_scores[i+3] + skew_scores[i+6]
                            })
                
                    rows.append(transcript_position)
        
    # Create DataFrame
    df = pd.DataFrame(rows)
    return df


# Create the DataFrame
aggregated_df = create_aggregated_dataframe(data_list, sequence_proportions_1, sequence_proportions_2, sequence_proportions_3)

# %%
aggregated_df.head()
# Out:
#      transcript_id transcript_position  proportion_1  proportion_2  \
# 0  ENST00000000233                 244      0.056173      0.055689
# 1  ENST00000000233                 261      0.041284      0.070807
# 2  ENST00000000233                 316      0.055508      0.083324
# 3  ENST00000000233                 332      0.063051      0.065119
# 4  ENST00000000233                 368      0.056099      0.063420
#
#    proportion_3  pos  diff_1_1  diff_1_2   diff_1_3  diff_2_1  ...  max_1c  \
# 0      0.054655  244  0.001109  3.158378   2.210811 -0.002028  ...   44.60
# 1      0.053267  261  0.000204  0.010110  -1.791860  0.000897  ...   42.60
# 2      0.051150  316 -0.000154  0.702162  -6.528649  0.000140  ...   24.68
# 3      0.048015  332 -0.001988 -3.577150 -31.518500 -0.002531  ...   37.59
# 4      0.049935  368  0.000779 -0.544747   4.030303 -0.001460  ...   61.31
#
#    min_1c  skewness_1c  kurtosis_1c     mean_2c     var_2c  max_2c  min_2c  \
# 0   3.583     3.407331     4.500760  330.186486  38.454656   353.3   286.1
# 1   2.423    10.001174    43.263423  311.861628  27.536551   334.0   283.0
# 2   2.930     4.082764    15.271188  293.787027  14.695492   313.2   274.1
# 3   3.504     8.399099    52.268315  316.345500  26.190777   337.7   284.9
# 4   4.870     9.803483    99.653998  325.057576  17.500533   346.5   299.6
#
#    skewness_2c  kurtosis_2c
# 0    -3.600214    11.742933
# 1    -0.779251     2.807860
# 2    -0.536376     2.783766
# 3    -1.707681    11.218923
# 4    -0.834535     2.593209
#
# [5 rows x 85 columns]

# %%
# set transcript_position to type int 
df_labels['transcript_position'] = df_labels['transcript_position'].astype(int)
aggregated_df['transcript_position'] = aggregated_df['transcript_position'].astype(int)

# %%
# perform left join with aggregated_df and labels_df to get gene_id and label 
df_full = pd.merge(aggregated_df, df_labels[['gene_id','transcript_id', 'transcript_position', 'label']],
                   on=['transcript_id', 'transcript_position'], how='left')
print(df_full.columns)
# drop transcript_id and position -> why? 
df = df_full.drop([
    'transcript_id',
    'transcript_position',
], axis = 1)
# Out:
# Index(['transcript_id', 'transcript_position', 'proportion_1', 'proportion_2',
#        'proportion_3', 'pos', 'diff_1_1', 'diff_1_2', 'diff_1_3', 'diff_2_1',
#        'diff_2_2', 'diff_2_3', 'length', 'mean_0', 'var_0', 'max_0', 'min_0',
#        'skewness_0', 'kurtosis_0', 'mean_1', 'var_1', 'max_1', 'min_1',
#        'skewness_1', 'kurtosis_1', 'mean_2', 'var_2', 'max_2', 'min_2',
#        'skewness_2', 'kurtosis_2', 'mean_3', 'var_3', 'max_3', 'min_3',
#        'skewness_3', 'kurtosis_3', 'mean_4', 'var_4', 'max_4', 'min_4',
#        'skewness_4', 'kurtosis_4', 'mean_5', 'var_5', 'max_5', 'min_5',
#        'skewness_5', 'kurtosis_5', 'mean_6', 'var_6', 'max_6', 'min_6',
#        'skewness_6', 'kurtosis_6', 'mean_7', 'var_7', 'max_7', 'min_7',
#        'skewness_7', 'kurtosis_7', 'mean_8', 'var_8', 'max_8', 'min_8',
#        'skewness_8', 'kurtosis_8', 'mean_0c', 'var_0c', 'max_0c', 'min_0c',
#        'skewness_0c', 'kurtosis_0c', 'mean_1c', 'var_1c', 'max_1c', 'min_1c',
#        'skewness_1c', 'kurtosis_1c', 'mean_2c', 'var_2c', 'max_2c', 'min_2c',
#        'skewness_2c', 'kurtosis_2c', 'gene_id', 'label'],
#       dtype='object')

# %%
# Correlation heatmap
correlation_df = df.drop(['gene_id'], axis=1)
correlation_matrix = correlation_df.corr()
label_correlations = correlation_matrix['label'].drop('label')

plt.figure(figsize=(4, 30))
sns.heatmap(label_correlations.to_frame(), annot=True, cmap='coolwarm', cbar=True)
plt.title('Feature Correlation with Label')
plt.show()

# %%
df_final = df_full.copy()

y = df_final[['label', 'transcript_id', 'transcript_position', 'gene_id']]
x = df_final.drop(['label'], axis=1)
print(x.columns)
# Extra features to drop if merged with clustering features
# x = df_final.drop(['label', 'position', 'rna_sequence'], axis=1)

print(df_final.shape[0])
# Out:
# Index(['transcript_id', 'transcript_position', 'proportion_1', 'proportion_2',
#        'proportion_3', 'pos', 'diff_1_1', 'diff_1_2', 'diff_1_3', 'diff_2_1',
#        'diff_2_2', 'diff_2_3', 'length', 'mean_0', 'var_0', 'max_0', 'min_0',
#        'skewness_0', 'kurtosis_0', 'mean_1', 'var_1', 'max_1', 'min_1',
#        'skewness_1', 'kurtosis_1', 'mean_2', 'var_2', 'max_2', 'min_2',
#        'skewness_2', 'kurtosis_2', 'mean_3', 'var_3', 'max_3', 'min_3',
#        'skewness_3', 'kurtosis_3', 'mean_4', 'var_4', 'max_4', 'min_4',
#        'skewness_4', 'kurtosis_4', 'mean_5', 'var_5', 'max_5', 'min_5',
#        'skewness_5', 'kurtosis_5', 'mean_6', 'var_6', 'max_6', 'min_6',
#        'skewness_6', 'kurtosis_6', 'mean_7', 'var_7', 'max_7', 'min_7',
#        'skewness_7', 'kurtosis_7', 'mean_8', 'var_8', 'max_8', 'min_8',
#        'skewness_8', 'kurtosis_8', 'mean_0c', 'var_0c', 'max_0c', 'min_0c',
#        'skewness_0c', 'kurtosis_0c', 'mean_1c', 'var_1c', 'max_1c', 'min_1c',
#        'skewness_1c', 'kurtosis_1c', 'mean_2c', 'var_2c', 'max_2c', 'min_2c',
#        'skewness_2c', 'kurtosis_2c', 'gene_id'],
#       dtype='object')
# 121838

# %%
# split data by gene_id

unique_gene_ids =  x['gene_id'].unique()

train_gene_ids, test_gene_ids = train_test_split(
    unique_gene_ids, test_size=0.1, random_state=42
)

# Create train and test sets by filtering based on gene_id
X_train = x[x['gene_id'].isin(train_gene_ids)]
X_test = x[x['gene_id'].isin(test_gene_ids)]

y_train = y[y['gene_id'].isin(train_gene_ids)]
y_test = y[y['gene_id'].isin(test_gene_ids)]

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# check if ratio of 0 to 1 is somewhat similar 
print(y_train['label'].mean())
print(y_test['label'].mean())

X_train = X_train.drop(['transcript_id', 'transcript_position', 'gene_id'], axis = 1)
X_test = X_test.drop(['transcript_id', 'transcript_position', 'gene_id'], axis = 1)
y_train = y_train['label']
y_test = y_test['label']

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (109078, 86) (12760, 86) (109078, 4) (12760, 4)
# 0.04478446616182915
# 0.04623824451410658
# (109078, 83) (12760, 83) (109078,) (12760,)

# %%
# Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# XGBoost

# %%
### XBOOST
print("XGBoost")
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss',  scale_pos_weight = pos_weight, class_weight = class_weights) #or logloss
model.fit(X_train_scaled, y_train)
x_test = X_test_scaled
y_check = y_test
y_pred = model.predict(x_test)

y_pred = model.predict(x_test)
y_pred_proba = model.predict_proba(x_test)[:, 1]

accuracy = accuracy_score(y_check, y_pred)
roc_auc = roc_auc_score(y_check, y_pred_proba)
precision, recall, _ = precision_recall_curve(y_check, y_pred_proba)
pr_auc = auc(recall, precision)  # Calculate PR AUC
report = classification_report(y_check, y_pred)

# Output the results
print("XGBoost - Base model")
print(f"Accuracy: {accuracy}")
print(f"ROC AUC: {roc_auc}")
print(f"PR AUC: {pr_auc}")
print(report)
# Out:
# XGBoost
# /Users/yunethirikhin/opt/anaconda3/envs/DSA4262/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [01:58:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "class_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Base model
# Accuracy: 0.9253134796238245
# ROC AUC: 0.9020323663356684
# PR AUC: 0.4746621091887893
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96     12170
#            1       0.34      0.65      0.45       590
#
#     accuracy                           0.93     12760
#    macro avg       0.66      0.80      0.70     12760
# weighted avg       0.95      0.93      0.94     12760

# %%
# Finding Best Params 

# Define the parameter grid
param_grid = {
    'n_estimators': [1000, 1100, 1200], # Default = 100
    'max_depth': [11, 12, 13], # Default = 6
    'learning_rate': [0.01, 0.05, 0.1], 
    'subsample': [0.8, 0.9, 1.0], # Default = 1
    'colsample_bytree': [0.8, 0.9, 1.0], # Default = 1
    'gamma': [0, 1], # Default = 0
    'min_child_weight': range(1,6),
    'max_delta_step': [0, 1, 2],
}

xgb_clf = XGBClassifier(random_state=42)

# Perform Randomized Search
random_search = RandomizedSearchCV(
    estimator=xgb_clf,
    param_distributions=param_grid,
    n_iter=50,
    scoring='roc_auc',
    cv=StratifiedKFold(n_splits=3),
    random_state=42,
    n_jobs=-1,
    verbose=2, 
)

random_search.fit(X_train_scaled, y_train)

# Best parameters
print("Best parameters found: ", random_search.best_params_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=3, n_estimators=1200, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=3, n_estimators=1200, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=3, n_estimators=1200, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1100, subsample=1.0; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1100, subsample=1.0; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1100, subsample=1.0; total time= 2.9min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=13, min_child_weight=4, n_estimators=1200, subsample=1.0; total time= 3.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=13, min_child_weight=4, n_estimators=1200, subsample=1.0; total time= 3.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=13, min_child_weight=4, n_estimators=1200, subsample=1.0; total time= 3.1min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 3.1min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 3.0min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 4.9min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 4.9min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 6.8min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 6.8min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 4.9min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 2.9min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 6.4min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=1, max_depth=13, min_child_weight=4, n_estimators=1100, subsample=1.0; total time= 2.3min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=0.9; total time= 1.8min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=1, max_depth=13, min_child_weight=4, n_estimators=1100, subsample=1.0; total time= 2.3min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=1, max_depth=13, min_child_weight=4, n_estimators=1100, subsample=1.0; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 2.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 2.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 2.6min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.5min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.6min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=0.9; total time= 3.7min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=0.9; total time= 3.7min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=0.9; total time= 3.8min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_delta_step=2, max_depth=13, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 1.2min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_delta_step=2, max_depth=13, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 1.2min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_delta_step=2, max_depth=13, min_child_weight=2, n_estimators=1200, subsample=0.9; total time= 1.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=11, min_child_weight=5, n_estimators=1200, subsample=0.9; total time= 2.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.5min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=11, min_child_weight=5, n_estimators=1200, subsample=0.9; total time= 2.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=11, min_child_weight=5, n_estimators=1200, subsample=0.9; total time= 2.2min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.0min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=1, max_depth=11, min_child_weight=3, n_estimators=1100, subsample=0.8; total time= 3.2min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=1, max_depth=11, min_child_weight=3, n_estimators=1100, subsample=0.8; total time= 3.2min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.0min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.0min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=1, max_depth=11, min_child_weight=3, n_estimators=1100, subsample=0.8; total time= 3.2min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=0.8; total time= 2.3min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=0.8; total time= 2.3min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=0.8; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=1.0; total time=  53.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=5, n_estimators=1100, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=5, n_estimators=1100, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=5, n_estimators=1100, subsample=0.8; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=1.0; total time=  52.2s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=1.0; total time=  52.7s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1200, subsample=0.8; total time=  53.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1100, subsample=0.9; total time= 3.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1100, subsample=0.9; total time= 3.1min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1200, subsample=0.8; total time=  52.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1100, subsample=0.9; total time= 3.2min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1200, subsample=0.8; total time=  54.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1100, subsample=0.9; total time= 2.9min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=0.9; total time=  46.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=0.9; total time=  46.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1100, subsample=0.9; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=13, min_child_weight=1, n_estimators=1100, subsample=0.9; total time= 2.9min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=12, min_child_weight=4, n_estimators=1100, subsample=0.9; total time= 2.2min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1000, subsample=0.9; total time=  44.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=12, min_child_weight=4, n_estimators=1100, subsample=0.9; total time= 2.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=2, max_depth=12, min_child_weight=4, n_estimators=1100, subsample=0.9; total time= 2.2min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 2.8min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 2.8min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 2.8min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=11, min_child_weight=1, n_estimators=1100, subsample=0.8; total time= 4.3min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=11, min_child_weight=1, n_estimators=1100, subsample=0.8; total time= 4.3min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=11, min_child_weight=1, n_estimators=1100, subsample=0.8; total time= 4.3min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=1.0; total time= 4.1min
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=1.0; total time= 4.2min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=13, min_child_weight=2, n_estimators=1000, subsample=0.9; total time=  50.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=2, n_estimators=1100, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=2, n_estimators=1100, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=4, n_estimators=1100, subsample=0.8; total time= 3.1min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=4, n_estimators=1100, subsample=0.8; total time= 3.1min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=13, min_child_weight=2, n_estimators=1000, subsample=0.9; total time=  47.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=2, n_estimators=1100, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=13, min_child_weight=2, n_estimators=1000, subsample=0.9; total time=  47.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=1.0; total time= 4.3min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=4, n_estimators=1100, subsample=0.8; total time= 3.2min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=0.9; total time= 1.3min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=11, min_child_weight=2, n_estimators=1000, subsample=0.9; total time= 2.1min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=11, min_child_weight=2, n_estimators=1000, subsample=0.9; total time= 2.1min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=11, min_child_weight=2, n_estimators=1000, subsample=0.9; total time= 2.1min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=4, n_estimators=1000, subsample=0.9; total time=  51.1s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=4, n_estimators=1000, subsample=0.9; total time=  52.4s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=2, max_depth=13, min_child_weight=4, n_estimators=1000, subsample=0.9; total time=  52.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.9min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.9min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.9min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.8min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.8min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 5.3min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 5.2min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 5.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=11, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=11, min_child_weight=3, n_estimators=1100, subsample=0.9; total time=  48.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=11, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 2.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=11, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=12, min_child_weight=3, n_estimators=1200, subsample=0.8; total time= 2.6min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=11, min_child_weight=3, n_estimators=1100, subsample=0.9; total time=  46.5s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=11, min_child_weight=3, n_estimators=1100, subsample=0.9; total time=  46.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=1.0; total time= 3.3min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=1.0; total time= 3.2min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=1.0; total time= 3.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=11, min_child_weight=4, n_estimators=1100, subsample=0.8; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=11, min_child_weight=4, n_estimators=1100, subsample=0.8; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=1, max_depth=11, min_child_weight=4, n_estimators=1100, subsample=0.8; total time= 1.9min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=1, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 1.5min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=1, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 1.5min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=1, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.8; total time= 1.6min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=5, n_estimators=1000, subsample=0.8; total time=  57.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=5, n_estimators=1000, subsample=0.8; total time=  55.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=5, n_estimators=1000, subsample=0.8; total time=  53.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 5.4min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 5.5min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=12, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 5.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=0.8; total time= 4.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=0.8; total time= 4.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_delta_step=1, max_depth=12, min_child_weight=2, n_estimators=1000, subsample=0.8; total time= 4.4min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=1.0; total time=  49.3s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=1.0; total time=  48.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=1, max_depth=11, min_child_weight=4, n_estimators=1200, subsample=1.0; total time= 2.9min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=1, max_depth=11, min_child_weight=4, n_estimators=1200, subsample=1.0; total time= 2.9min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=11, min_child_weight=4, n_estimators=1200, subsample=0.9; total time= 4.0min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=11, min_child_weight=4, n_estimators=1200, subsample=0.9; total time= 4.0min
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.1, max_delta_step=1, max_depth=12, min_child_weight=3, n_estimators=1100, subsample=1.0; total time=  47.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_delta_step=2, max_depth=11, min_child_weight=4, n_estimators=1200, subsample=0.9; total time= 4.0min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=1, max_depth=11, min_child_weight=4, n_estimators=1200, subsample=1.0; total time= 2.7min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=2, max_depth=11, min_child_weight=2, n_estimators=1000, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=2, max_depth=11, min_child_weight=2, n_estimators=1000, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.05, max_delta_step=2, max_depth=11, min_child_weight=2, n_estimators=1000, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  50.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  50.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_delta_step=0, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  49.9s
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=11, min_child_weight=5, n_estimators=1200, subsample=0.9; total time= 2.5min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=11, min_child_weight=5, n_estimators=1200, subsample=0.9; total time= 2.5min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.9; total time= 3.6min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_delta_step=2, max_depth=11, min_child_weight=5, n_estimators=1200, subsample=0.9; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.9; total time= 3.4min
# [CV] END colsample_bytree=0.8, gamma=1, learning_rate=0.01, max_delta_step=0, max_depth=12, min_child_weight=1, n_estimators=1200, subsample=0.9; total time= 3.4min
# Best parameters found:  {'subsample': 0.9, 'n_estimators': 1100, 'min_child_weight': 5, 'max_depth': 13, 'max_delta_step': 0, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.8}

# %%
# Set class weights
class_weights = {0: 1, 1: 10}

# %%
# heuristic for scale_pos_weight

from collections import Counter

counter = Counter(y['label'])


estimate = counter[0] / counter[1]

pos_weight = estimate

# %%
best_params = {'subsample': 0.8, 'n_estimators': 800, 'max_depth': 9, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8}
#best_params = {'subsample': 0.9, 'n_estimators': 1000, 'max_depth': 11, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.9}
#best_params = {'subsample': 0.9, 'n_estimators': 1100, 'min_child_weight': 6, 'max_depth': 13, 'max_delta_step': 0, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.8}

print("XGBoost")
model = XGBClassifier(
    use_label_encoder=False, 
    scale_pos_weight = pos_weight, 
    eval_metric='logloss', 
    **best_params)
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)
y_pred_proba = model.predict_proba(X_test_scaled)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
pr_auc = auc(recall, precision)  # Calculate PR AUC
report = classification_report(y_test, y_pred)

# Output the results
print("Test Data Set - Param Searched Best XGB Model")
print(f"Accuracy: {accuracy}")
print(f"ROC AUC: {roc_auc}")
print(f"PR AUC: {pr_auc}")
print(report)

model_xgb = model
# Out:
# XGBoost
# /Users/yunethirikhin/opt/anaconda3/envs/DSA4262/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [01:58:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Test Data Set - Param Searched Best XGB Model
# Accuracy: 0.9602664576802508
# ROC AUC: 0.9112732058549085
# PR AUC: 0.5090970766201738
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     12170
#            1       0.60      0.41      0.49       590
#
#     accuracy                           0.96     12760
#    macro avg       0.79      0.70      0.73     12760
# weighted avg       0.95      0.96      0.96     12760

# %%
np.savetxt('output_xgb_v2.csv', y_pred_proba, delimiter=',')

# %%
check = pd.read_csv('output_xgb_v2.csv', header = None)

# %%
check[check[0]>0.5]
# Out:
#               0
# 17     0.998860
# 19     0.851481
# 35     0.889132
# 36     0.936091
# 37     0.589085
# ...         ...
# 12425  0.993220
# 12481  0.747453
# 12482  0.916126
# 12670  0.631795
# 12687  0.626421
#
# [401 rows x 1 columns]

# %%
y[y['label'] == 1]
# Out:
#         label    transcript_id  transcript_position          gene_id
# 17          1  ENST00000000233                  913  ENSG00000004059
# 52          1  ENST00000000412                 2440  ENSG00000003056
# 53          1  ENST00000000412                 2462  ENSG00000003056
# 55          1  ENST00000000412                 2499  ENSG00000003056
# 229         1  ENST00000007390                 1096  ENSG00000007520
# ...       ...              ...                  ...              ...
# 121828      1  ENST00000641834                 1093  ENSG00000167747
# 121831      1  ENST00000641834                 1255  ENSG00000167747
# 121832      1  ENST00000641834                 1259  ENSG00000167747
# 121833      1  ENST00000641834                 1348  ENSG00000167747
# 121835      1  ENST00000641834                 1531  ENSG00000167747
#
# [5475 rows x 4 columns]
